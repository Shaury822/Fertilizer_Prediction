# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaury822/Fertilizer_Prediction/blob/main/data_science_job_salaries_1_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Data Science Jobs Salaries.csv")
df.head(8)
# Out:
#   work_year experience_level employment_type                  job_title  \
# 0     2021e               EN              FT    Data Science Consultant
# 1      2020               SE              FT             Data Scientist
# 2     2021e               EX              FT       Head of Data Science
# 3     2021e               EX              FT               Head of Data
# 4     2021e               EN              FT  Machine Learning Engineer
# 5     2021e               SE              FT     Data Analytics Manager
# 6      2020               MI              FT         Research Scientist
# 7      2020               MI              FT               Data Analyst
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   54000             EUR          64369                 DE            50
# 1   60000             EUR          68428                 GR           100
# 2   85000             USD          85000                 RU             0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           245 non-null    object
#  1   experience_level    245 non-null    object
#  2   employment_type     245 non-null    object
#  3   job_title           245 non-null    object
#  4   salary              245 non-null    int64
#  5   salary_currency     245 non-null    object
#  6   salary_in_usd       245 non-null    int64
#  7   employee_residence  245 non-null    object
#  8   remote_ratio        245 non-null    int64
#  9   company_location    245 non-null    object
#  10  company_size        245 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 21.2+ KB

# %%
df.shape
# Out:
# (245, 11)

# %%
df.dtypes
# Out:
# work_year             object
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
# !pip install country_converter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import country_converter as coco
cc = coco.CountryConverter()
df['company_location'] = cc.convert(df['company_location'], to='name_short')
df['employee_residence'] = cc.convert(df['employee_residence'], to='name_short')

# %%
df['experience_level'].unique()
# Out:
# array(['EN', 'SE', 'EX', 'MI'], dtype=object)

# %%
df['experience_level'].value_counts()
# Out:
# experience_level
# MI    102
# SE     77
# EN     54
# EX     11
# Name: count, dtype: int64

# %%
df['experience_level']=df['experience_level'].map({'SE':1,'MI':2,'EN':3,'EX':4})

# %%
df['employment_type'].value_counts()
# Out:
# employment_type
# FT    230
# PT      7
# CT      4
# FL      3
# Name: count, dtype: int64

# %%
df['employment_type']=df['employment_type'].map({'FT':'Full-time','PT':'part time','CT':'contract','FL':'Freelance'})#OUTPUT NOT COME

# %%
df['company_size'].value_counts()
# Out:
# company_size
# L    131
# S     58
# M     55
# Name: count, dtype: int64

# %%
df['company_size']=df['company_size'].map({'S':1,'M':2,'L':3})

# %%
df['company_size']=df['company_size'].map({'S':'small','M':'medium','L':'large'})

# %%
df.drop(['salary','salary_currency'],axis=1,inplace=True)

# %%
df.rename(columns={'salary_in_usd':'salary'},inplace=True)

# %%
df['work_year'].value_counts()
# Out:
# work_year
# 2021e    178
# 2020      66
# Name: count, dtype: int64

# %%
df['remote_ratio'].value_counts()
# Out:
# remote_ratio
# 100    134
# 50      70
# 0       40
# Name: count, dtype: int64

# %%
df.rename(columns={'remote_ratio':'remote'},inplace=True)

# %%
df.rename(columns={'remote_ratio':'job_type'},inplace=True)

# %%
df['remote'] = df['remote'].map({0:'onsite',50:'hybrid',100:'remote'})

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Data Scientist                              58
# Data Engineer                               38
# Machine Learning Engineer                   20
# Data Analyst                                20
# Research Scientist                          10
# Data Science Consultant                      7
# Big Data Engineer                            6
# BI Data Analyst                              5
# Lead Data Engineer                           5
# AI Scientist                                 5
# Data Science Manager                         5
# Principal Data Scientist                     5
# Machine Learning Scientist                   4
# Director of Data Science                     4
# Data Analytics Engineer                      3
# Data Analytics Manager                       3
# Lead Data Analyst                            3
# ML Engineer                                  3
# Computer Vision Engineer                     3
# Business Data Analyst                        3
# ...

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'employee_residence', 'remote', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df.head()
# Out:
#   work_year  experience_level employment_type                  job_title  \
# 0     2021e                 3       Full-time    Data Science Consultant
# 1      2020                 1       Full-time             Data Scientist
# 2     2021e                 4       Full-time       Head of Data Science
# 3     2021e                 4       Full-time               Head of Data
# 4     2021e                 3       Full-time  Machine Learning Engineer
#
#    salary employee_residence  remote company_location company_size
# 0   64369            Germany  hybrid          Germany          NaN
# 1   68428             Greece  remote    United States          NaN
# 2   85000             Russia  onsite           Russia          NaN
# 3  230000             Russia  hybrid           Russia          NaN
# 4  125000      United States  remote    United States          NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_palette('winter')
ax = sns.histplot(df['salary'], kde=True)

ax.set_title('Salary Distribution', fontdict={'fontsize': 16})

plt.show()

# %%
mean_salary_by_experience_level = df.groupby('experience_level')['salary'].mean().sort_values()

# %%
mean_s_exp_lv=df.groupby('experience_level')['salary'].mean().sort_values()

# %%
mean_s_emp_type=df.groupby('employment_type')['salary'].mean().sort_values()

# %%
sns.set_style('whitegrid')
sns.set_palette('spring')
plt.figure(figsize=(14, 7))
plt.subplot(1, 2, 1)
ax1 = sns.barplot(data=df, x='experience_level', y='salary', estimator='mean')
ax1.set_title('Mean Salary vs Experience Level', fontdict={'fontsize': 16})
plt.subplot(1, 2, 2)
ax2 = sns.violinplot(data=df, x='experience_level', y='salary')
ax2.set_title('Experience Level vs Salary', fontdict={'fontsize': 16})
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.set_palette('autumn')
plt.subplot(1,2,1)
ax=sns.barplot(data=df,x='employment_type',y='salary')
ax.set_title('employment type vs salary')
fontdict={'fontsize':16}

# %%
mean_s_cmp_size=df.groupby('company_size')['salary'].mean().sort_values()

# %%
plt.figure(figsize=(14,7))
sns.set_palette('spring')
plt.subplot(1,2,1)
ax=sns.barplot(data=df,x='company_size',y='salary')

# %%
plt.figure(figsize=(14, 7))
sns.set_palette('spring')
plt.subplot(1, 2, 1)
ax = sns.barplot(data=df, x='company_size', y='salary')
ax.set_title('Average Salary by Company Size', fontdict={'fontsize': 16})
ax.set_xlabel('Company Size')
ax.set_ylabel('Average Salary')
# Out:
# Text(0, 0.5, 'Average Salary')

# %%
mean_s_jtype=df.groupby('job_title')['salary'].mean().sort_values()

# %%
plt.figure(figsize=(14,7))
sns.set_palette('spring')
plt.subplot(1,2,1)
ax=sns.barplot(x=mean_s_jtype.index,y=mean_s_jtype.values)
ax.set_title('job type vs salary')
# Out:
# Text(0.5, 1.0, 'job type vs salary')

# %%
plt.figure(figsize=(14, 7))
sns.set_palette('Set2')
ax = sns.barplot(data=df, x='job_title', y='salary', hue='experience_level')
ax.set_title('Job Title vs Salary', fontdict={'fontsize': 16})
ax.set_xlabel('Job Title')
ax.set_ylabel('Average Salary')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.set_palette('Set2')
ax=df['remote_ratio'].value_counts().plot(kind='pie')
ax.set_title('remote ratio vs salary', fontdict={'fontsize':16})
# Out:
# Text(0.5, 1.0, 'remote ratio vs salary')

# %%
df.groupby('job_title')['salary'].mean().sort_values(ascending=False)
# Out:
# job_title
# Data Science Manager                        2.303240e+06
# BI Data Analyst                             2.271454e+06
# Data Scientist                              9.865809e+05
# Big Data Engineer                           5.850000e+05
# Lead Data Analyst                           5.690000e+05
# Financial Data Analyst                      4.500000e+05
# Product Data Analyst                        4.500000e+05
# Machine Learning Engineer                   4.382920e+05
# Applied Machine Learning Scientist          4.230000e+05
# 3D Computer Vision Researcher               4.000000e+05
# Principal Data Engineer                     3.925000e+05
# AI Scientist                                3.428000e+05
# Data Engineer                               3.222796e+05
# Head of Data                                2.325000e+05
# Principal Data Scientist                    2.158000e+05
# Director of Data Science                    1.857500e+05
# ...

# %%
unique_job_titles = df['job_title'].unique()
top_ds_roles = pd.Series(data=list(unique_job_titles)).apply(lambda x: x if list(df['job_title']).count(x) > 1 else 0)

# %%
top_ds_roles=top_ds_roles_
ax=sns.barplot(y=top_ds_roles.index,x=top_ds_roles)
ax.set_xlabel('mean salary')
ax.set_title('top ds roles according to mean salary',fontdict={'fontsize':16})
# Out:
# Text(0.5, 1.0, 'top ds roles according to mean salary')

# %%
plt.subplot(1,2,2)
top_dr=df['remote_ratio'].value_counts()[:10]
ax=sns.barplot(x=top_dr,y=top_dr.index)
ax.set_xlabel('job openings')
ax.set_title('top 10 data scirnce roles with highest number of openings',fontdict={'fontsize':16})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2600351892.py in <cell line: 0>()
#       1 plt.subplot(1,2,2)
#       2 top_dr=df['remote_ratio'].value_counts()[:10]
# ----> 3 ax=sns.barplot(x=top_dry,y=top_dr.index)
#       4 ax.set_xlabel('job openings')
#       5 ax.set_title('top 10 data scirnce roles with highest number of openings',fontdict={'fontsize':16})
#
# NameError: name 'top_dry' is not defined

# %%
top_cmp_locations=df.groupby('company_location')['salary'].mean().sort_values(ascending=False)[:10]

# %%
plt.figure(figsize=(20, 5))

# %%
ax = sns.barplot(y=top_cmp_locations.index, x=top_cmp_locations)
ax.set_xlabel('Mean Salary')
ax.set_title('Top 10 countries according to DS mean salaries', fontdict={'fontsize': 16})
# Out:
# Text(0.5, 1.0, 'Top 10 countries according to DS mean salaries')

# %%
top_cl = df['company_location'].value_counts()[:10]
plt.subplot(1, 2, 2)
ax=sns.barplot(x=top_cl, y=top_cl.index)
ax.set_xlabel('Job Openings')
ax.set_title('Top 10 countries with highest number of job openings', fontdict={'fontsize': 16})
# Out:
# Text(0.5, 1.0, 'Top 10 countries with highest number of job openings')

# %%
top_emp_residence = df.groupby('employee_residence')['salary'].mean().sort_values(ascending=False)[:10]

# %%
plt.figure(figsize=(20, 5))

# %%
plt.subplot(1, 2, 1)
ax = sns.barplot(y=top_emp_residence.index, x=top_emp_residence)
ax.set_xlabel('Mean Salary')
ax.set_title('Top 10 countries according to DS mean salaries', fontdict={'fontsize': 16})
# Out:
# Text(0.5, 1.0, 'Top 10 countries according to DS mean salaries')

# %%
plt.subplot(1, 2, 2)
top_er = df['employee_residence'].value_counts()[:10]
ax = sns.barplot(x=top_er, y=top_er.index)
ax.set_xlabel('Job Openings')
ax.set_title('Top 10 countries with highest number of job openings', fontdict={'fontsize': 16})
# Out:
# Text(0.5, 1.0, 'Top 10 countries with highest number of job openings')

# %%
plt.figure(figsize=(10, 5))
sns.set_palette('Set2')
ax = sns.countplot(data=df, x='company_size', hue='remote')
ax.set_title('Company Size VS Job Types Counts', fontdict={'fontsize': 16})
# Out:
# Text(0.5, 1.0, 'Company Size VS Job Types Counts')
